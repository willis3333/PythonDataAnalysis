# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/hiero/PycharmProjects/scientificProject/data/Pokemon.csv')
df.head(n=10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
df.columns = df.columns.str.upper()
df.head()
# Out:
#    #                   NAME TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df[df['LEGENDARY']==True].head(10)
# Out:
#        #                 NAME    TYPE 1    TYPE 2  TOTAL   HP  ATTACK  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150  MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 262  243               Raikou  Electric       NaN    580   90      85
# 263  244                Entei      Fire       NaN    580  115     115
# 264  245              Suicune     Water       NaN    580  100      75
# 269  249                Lugia   Psychic    Flying    680  106      90
#
#      DEFENSE  SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# ...

# %%
df = df.set_index('NAME')

# %%
#removing text before "Mega" on indesis containing "Mega"
df.index = df.index.str.replace(".*(?=Mega)", "")
df.head(10)
# Out:
#                   # TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur         1  Grass  Poison    318  45      49       49       65
# Ivysaur           2  Grass  Poison    405  60      62       63       80
# Venusaur          3  Grass  Poison    525  80      82       83      100
# Mega Venusaur     3  Grass  Poison    625  80     100      123      122
# Charmander        4   Fire     NaN    309  39      52       43       60
# Charmeleon        5   Fire     NaN    405  58      64       58       80
# Charizard         6   Fire  Flying    534  78      84       78      109
# Mega Charizard X  6   Fire  Dragon    634  78     130      111      130
# Mega Charizard Y  6   Fire  Flying    634  78     104       78      159
# Squirtle          7  Water     NaN    314  44      48       65       50
#
#                   SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# Bulbasaur              65     45           1      False
# ...

# %%
df=df.drop(['#'], axis=1)

# %%
print('The columns of this Pokemon dataset are: ', df.columns)
# Out:
# The columns of this Pokemon dataset are:  Index(['TYPE 1', 'TYPE 2', 'TOTAL', 'HP', 'ATTACK', 'DEFENSE', 'SP. ATK',
#        'SP. DEF', 'SPEED', 'GENERATION', 'LEGENDARY'],
#       dtype='object')

# %%
print('The shape of this Pokemon dataframe is:', df.shape)
# Out:
# The shape of this Pokemon dataframe is: (800, 11)

# %%
df['TYPE 2'].fillna(df['TYPE 1'], inplace=True) #filling Nan TYPE 2 values with corresponding TYPE 1 value
df.head(10)
# Out:
#                  TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Bulbasaur         Grass  Poison    318  45      49       49       65       65
# Ivysaur           Grass  Poison    405  60      62       63       80       80
# Venusaur          Grass  Poison    525  80      82       83      100      100
# Mega Venusaur     Grass  Poison    625  80     100      123      122      120
# Charmander         Fire    Fire    309  39      52       43       60       50
# Charmeleon         Fire    Fire    405  58      64       58       80       65
# Charizard          Fire  Flying    534  78      84       78      109       85
# Mega Charizard X   Fire  Dragon    634  78     130      111      130       85
# Mega Charizard Y   Fire  Flying    634  78     104       78      159      115
# Squirtle          Water   Water    314  44      48       65       50       64
#
#                   SPEED  GENERATION  LEGENDARY
# NAME
# Bulbasaur            45           1      False
# ...

# %%
#using various retrieval methods to print specific data
print(df.loc['Bulbasaur'])
print(df.iloc[0])
# Out:
# TYPE 1         Grass
# TYPE 2        Poison
# TOTAL            318
# HP                45
# ATTACK            49
# DEFENSE           49
# SP. ATK           65
# SP. DEF           65
# SPEED             45
# GENERATION         1
# LEGENDARY      False
# Name: Bulbasaur, dtype: object
# TYPE 1         Grass
# TYPE 2        Poison
# TOTAL            318
# HP                45
# ATTACK            49
# DEFENSE           49
# SP. ATK           65
# SP. DEF           65
# SPEED             45
# GENERATION         1
# LEGENDARY      False
# Name: Bulbasaur, dtype: object

# %%
df[((df['TYPE 1']=='Fire') | (df['TYPE 1']=='Dragon')) & ((df['TYPE 2']=='Dragon') | (df['TYPE 2']=='Fire'))].head(5)
# Out:
#                  TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Charmander         Fire    Fire    309  39      52       43       60       50
# Charmeleon         Fire    Fire    405  58      64       58       80       65
# Mega Charizard X   Fire  Dragon    634  78     130      111      130       85
# Vulpix             Fire    Fire    299  38      41       40       50       65
# Ninetales          Fire    Fire    505  73      76       75       81      100
#
#                   SPEED  GENERATION  LEGENDARY
# NAME
# Charmander           65           1      False
# Charmeleon           80           1      False
# Mega Charizard X    100           1      False
# Vulpix               65           1      False
# Ninetales           100           1      False

# %%
print('Max HP: ',df['HP'].idxmax())
print('Max HP: ',df['HP'].argmax())
print('Max Defense:',df['DEFENSE'].idxmax())
print('Max Defense:',df['DEFENSE'].argmax())
# Out:
# Max HP:  Blissey
# Max HP:  261
# Max Defense: Mega Steelix
# Max Defense: 224

# %%
df.sort_values('TOTAL', ascending=False).head(10) #top 10 overall
# Out:
#                         TYPE 1    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  \
# NAME
# Mega Rayquaza           Dragon    Flying    780  105     180      100
# Mega Mewtwo Y          Psychic   Psychic    780  106     150       70
# Mega Mewtwo X          Psychic  Fighting    780  106     190      100
# KyogrePrimal Kyogre      Water     Water    770  100     150       90
# GroudonPrimal Groudon   Ground      Fire    770  100     180      160
# Arceus                  Normal    Normal    720  120     120      120
# KyuremWhite Kyurem      Dragon       Ice    700  125     120       90
# KyuremBlack Kyurem      Dragon       Ice    700  125     170      100
# Mega Salamence          Dragon    Flying    700   95     145      130
# Mega Metagross           Steel   Psychic    700   80     145      150
#
#                        SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# Mega Rayquaza              180      100    115           3       True
# ...

# %%
print('The unique Pokemon types are: ',df['TYPE 1'].unique())
print('The total number of unique Pokemon types are:',df['TYPE 1'].nunique())
# Out:
# The unique Pokemon types are:  ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']
# The total number of unique Pokemon types are: 18

# %%
print('The number of each Pokemon type is: ',df['TYPE 1'].value_counts())
print(df.groupby(['TYPE 2']).size().head(5))
print('The total number of Pokemon with bug in TYPE 1 is: ', (df['TYPE 1']=='Bug').sum())
# Out:
# The number of each Pokemon type is:  Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: TYPE 1, dtype: int64
# TYPE 2
# Bug         20
# Dark        30
# Dragon      29
# Electric    33
# Fairy       38
# dtype: int64
# The total number of Pokemon with bug in TYPE 1 is:  69

# %%
df_summary = df.describe() 
df_summary
# Out:
#            TOTAL          HP      ATTACK     DEFENSE     SP. ATK     SP. DEF  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             SPEED  GENERATION
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
bins=range(0,200,20) #they act as containers
plt.hist(df["ATTACK"],bins,histtype="bar",rwidth=1.2,color='#0ff0ff') #hist() is used to plot a histogram
plt.xlabel('Attack') #set the xlabel name
plt.ylabel('Count') #set the ylabel name
plt.plot()
plt.axvline(df['ATTACK'].mean(),linestyle='dashed',color='red') #draw a vertical line showing the average Attack value
plt.show()

# %%
fire=df[(df['TYPE 1']=='Fire') | ((df['TYPE 2'])=="Fire")] #fire contains all fire pokemons
water=df[(df['TYPE 1']=='Water') | ((df['TYPE 2'])=="Water")]  #all water pokemins
plt.scatter(fire.ATTACK.head(50),fire.DEFENSE.head(50),color='R',label='Fire',marker="*",s=50) #scatter plot
plt.scatter(water.ATTACK.head(50),water.DEFENSE.head(50),color='B',label="Water",s=25)
plt.xlabel("Attack")
plt.ylabel("DEFENCE")
plt.legend()
plt.plot()
fig=plt.gcf()  #get the current figure using .gcf()
fig.set_size_inches(12,6) #set the size for the figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     324         try:
# --> 325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError as err:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     324         try:
# --> 325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError as err:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     188     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 189         rgba = _to_rgba_no_colorcycle(c, alpha)
#     190         try:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     259             return c, c, c, alpha if alpha is not None else 1.
# ...
